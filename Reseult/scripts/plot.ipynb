# %%
import numpy as np 
import pandas as pd 
import os
from matplotlib import pyplot as plt
from scipy.spatial import distance

# %%
data= pd.read_csv('time_analysis.csv')
x0 =np.arange(0,len(data),1)

# %%
#draw graph of hazard_duration vs fault_duration
plt.plot(data['fault_duration'],data['hazard_duration'],'go',label='Sample')
plt.plot(data['fault_duration'],data['fault_duration'],'-',label='y=x',)
# plt.plot(x0,x0,color='r')
plt.xlabel('(a) Fault_duration (minute)', fontsize=14)
plt.ylabel('Hazard_duration(minute)', fontsize=14)

plt.legend(loc='upper right')
plt.show()

# plt.plot(x0,data['hazardendtime(T4)']-data['faultendtiome(T5)'],label='hazard_duration',color='g')
plt.bar(x0,data['hazardendtime(T4)']-data['faultendtiome(T5)'], alpha=0.9, width = 0.9, facecolor = 'skyblue', edgecolor = 'skyblue', label="Hazardendtime-Faultendtime", lw=1)
plt.xlabel('(b) Simulation No.', fontsize=14)
plt.ylabel('Time difference (minute)', fontsize=14)
plt.legend(loc='upper right')
plt.show()

# %%
plt.plot(x0,data['hazard_duration'],label='hazard_duration',color='g')
plt.plot(x0,data['fault_duration'],label='fault_duration',color='r')
plt.legend(loc='upper right')
plt.show()

# %%
#draw Time propogation of T1,3,4,5
plt.plot(x0,data['faulttime(T1)'],label='faulttime(T1)',color='y')
plt.plot(x0,data['hazardtime(T3)'],label='hazardtime(T3)',color='grey')
plt.plot(x0,data['faultendtiome(T5)'],label='faultendtiome(T5)',color='c')
plt.plot(x0,data['hazardendtime(T4)'],label='hazardendtime(T4)',color='orangered',linestyle='--')
plt.xlabel('Simulation No.', fontsize=10)
plt.ylabel('Time(minute)', fontsize=10)

plt.legend(loc='upper right')
plt.show()

# %%
distance.jaccard([0,1],[1,2])
hz_data = pd.read_csv("summary_monitor_hardware.csv")

# %%
print(hz_data["alert"].tolist())
# Out:
# ['row_32', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'row_27||row_27||row_32||row_38||row_32||row_38||row_32||row_38||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32', 'row_27||row_27||row_27||row_27||row_27||row_27||row_27||row_31||row_27||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_38||row_32||row_38||row_32||row_38||row_38||row_32||row_38||row_32||row_38||row_32||row_38', 'row_32||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32', 'row_27||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32', 'row_27||row_27||row_27||row_27||row_32||row_38||row_32||row_38||row_32||row_38||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_38||row_32||row_38||row_32', 'row_27||row_27||row_27||row_27||row_27||row_27||row_27||row_31||row_31||row_27||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_38||row_38||row_32||row_38||row_32||row_38||row_38||row_32||row_38||row_32||row_38||row_38||row_32||row_38||row_32||row_38||row_32||row_38', 'row_27||row_32||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38', 'row_32||row_27||row_32||row_38||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32', 'row_32||row_32||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_31||row_38||row_32||row_38||row_32||row_38||row_31||row_38', 'row_27||row_32||row_32||row_32||row_38||row_38||row_38||row_32||row_38||row_27||row_27||row_31||row_38||row_32||row_38||row_32||row_38||row_38', 'row_27||row_27||row_32||row_32||row_27||row_32||row_32||row_38||row_32||row_38||row_31||row_38||row_32||row_38||row_32||row_38||row_32||row_38', 'row_27||row_32||row_27||row_32||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_32||row_38||row_31||row_38||row_32||row_38||row_32||row_38||row_32||row_38', 'row_32||row_32||row_27||row_38||row_32||row_38||row_38||row_32||row_38||row_32||row_38||row_33||row_38||row_32||row_38||row_32||row_38', 'row_27||row_27||row_32||row_32||row_32||row_38||row_32||row_38||row_27||row_31||row_38||row_32||row_38||row_27||row_27||row_31', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'row_31', 'row_31', 'row_31||row_31', 'row_33||row_31', 'row_31||row_31', 'row_31||row_33||row_31', 'row_31||row_31', 'row_27||row_32||row_33||row_31', 'row_32||row_27||row_31||row_31||row_31', 'row_32||row_31||row_31', 'row_31||row_31', 'row_31||row_31', 'row_27||row_32||row_31||row_31', 'row_32||row_27||row_31||row_31', nan, nan, nan, nan, nan, nan, nan, 'row_27||row_32||row_32||row_32||row_32||row_32||row_38||row_27||row_32||row_38||row_38||row_27||row_38||row_27||row_38||row_32||row_27||row_38||row_38||row_32||row_27||row_38||row_27||row_38||row_32||row_27||row_38||row_38||row_32||row_27||row_38||row_27||row_38||row_38||row_32||row_27||row_38||row_38||row_38||row_38||row_38||row_38||row_38||row_38||row_38||row_38||row_38||row_38||row_38||row_38||row_38||row_38||row_38||row_38', 'row_32||row_32||row_32||row_32||row_32||row_27||row_32||row_27||row_27||row_27||row_38||row_32||row_27||row_38||row_38||row_32||row_27||row_38||row_38||row_38||row_38||row_32||row_38||row_38||row_32||row_27||row_38||row_38||row_38||row_38||row_32||row_27||row_38||row_38||row_38||row_38||row_32||row_38||row_3 ...

# %%
import re
pattern = re.compile(r'\d+')
alert = hz_data["alert"].tolist()
alert_list=[]
for i in range(len(alert)-1):  
    result = pattern.findall(str(alert[i]))
    if result:
#         alert_list.append(result)
        alert_list += result
print(np.array(alert_list))
# Out:
# ['32' '27' '27' ... '22' '22' '22']

# %%
unique_elements, counts_elements = np.unique(np.array(alert_list), return_counts=True)

# %%
print("Frequency of unique values of the said array:")
print(np.asarray((unique_elements, counts_elements)))
# Out:
# Frequency of unique values of the said array:
# [['2' '22' '27' '3' '31' '32' '33' '37' '38' '4' '5' '6']
#  ['19' '6523' '11407' '3' '630' '3026' '20' '2818' '15266' '123' '10'
#   '13']]
